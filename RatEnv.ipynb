# %%
import gymnasium as gym

# %%
def run_episode(env, policy=None, seed=0, max_steps=200, verbose=True):
    """Executa um único episódio. Retorna (total_reward, n_steps, last_info)."""
    obs, info = env.reset(seed=seed)
    env.action_space.seed(seed)
    if policy is None:
        policy = lambda o: env.action_space.sample()   # política aleatória

    total_reward, steps = 0.0, 0
    terminated = truncated = False
    while not (terminated or truncated):
        obs, reward, terminated, truncated, info = env.step(policy(obs))
        total_reward += reward
        steps += 1
        if steps >= max_steps:
            break

    if verbose:
        print(f"steps={steps:3d}  total_reward={total_reward:8.3f}  "
              f"terminated={terminated}  truncated={truncated}")
    return total_reward, steps, info

def make_scripted(path):
    """Cria uma política com estado que executa uma lista fixa de ações.

    Após consumir todas as ações da lista, a política passa a ficar parada.
    """
    cursor = {"i": 0}
    def policy(obs):
        i = cursor["i"]
        cursor["i"] += 1
        return path[i] if i < len(path) else 0
    return policy

# %% [markdown]
# # Implementação do ambiente

# %%
class RatEnv(gym.Env):
  pass

# %%
ratEnv = # instanciar objeto

# %% [markdown]
# ## Validação do ambiente

# %% [markdown]
# Validação da interface do ambiente utilizando o check_env da gymnasium

# %%
from gymnasium.utils.env_checker import check_env

check_env(ratEnv)

# %% [markdown]
# Validação da recompensa acumulada a partir de política

# %%
WORST_PATH = [1, 2]       # recompensa total acumulada -10
OPTIMAL_PATH  = [2, 2, 1] # recompensa total acumulada +11
SUB_OPTIMAL_PATH = [2, 1] # recompensa total acumulada -9

# %%
run_episode(ratEnv, policy=make_scripted(WORST_PATH), seed=0)

# %%
run_episode(ratEnv, policy=make_scripted(OPTIMAL_PATH), seed=0)

# %%
run_episode(ratEnv, policy=make_scripted(SUB_OPTIMAL_PATH), seed=0)
